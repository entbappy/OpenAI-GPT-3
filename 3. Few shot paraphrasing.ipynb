# %%
# !pip install --quiet openai
# Out:
#      |████████████████████████████████| 44 kB 978 kB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 146 kB 9.5 MB/s
#   Building wheel for openai (PEP 517) ... done

# %%
import os
import openai
import getpass

openai.api_key = getpass.getpass(prompt='Enter OpenAI API key:')
# Out:
# Enter OpenAI API key:··········

# %%
import os
import openai

sentence = "Four private astronauts launched to orbit by Elon Musk’s SpaceX returned to Earth Saturday evening, splashing down into the ocean off the east coast of Florida after a three-day mission."
created_prompt = "I am a diverse paraphraser. I will rewrite the original sentence with a completely different choice of words preserving the meaning:\n\nsentence: Once, a group of frogs was roaming around the forest in search of water.\nparaphrase: A gang of frogs was roaming about the woods in search of water once more.\n\nsentence: %s\nparaphrase:"%(sentence)

response = openai.Completion.create(
  engine="davinci-instruct-beta",
  prompt=created_prompt,
  temperature=0.9,
  max_tokens=103,
  top_p=1,
  frequency_penalty=0.6,
  presence_penalty=0.6,
  stop=["\n", "sentence"]
)

# %%
print (response)

print ("___________________________Original_____________________________")
print (sentence)

print ("___________________________Paraphrase_____________________________")
print (response['choices'][0]['text'].strip())
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": " Four private astronauts paid by Elon Musk\u2019s SpaceX launched to orbit by the rocket returned to Earth Saturday evening, splashing down into the ocean off the east coast of Florida after a three-day mission. "
#     }
#   ],
#   "created": 1669881855,
#   "id": "cmpl-6IYqFyrhOi3Ey4xJyAOFr2vcyc7w8",
#   "model": "davinci-instruct-beta",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 43,
#     "prompt_tokens": 115,
#     "total_tokens": 158
#   }
# }
# ___________________________Original_____________________________
# Four private astronauts launched to orbit by Elon Musk’s SpaceX returned to Earth Saturday evening, splashing down into the ocean off the east coast of Florida after a three-day mission.
# ___________________________Paraphrase_____________________________
# Four private astronauts paid by Elon Musk’s SpaceX launched to orbit by the rocket returned to Earth Saturday evening, splashing down into the ocean off the east coast of Florida after a three-day mission.
